# %% [markdown]
# <a href="https://colab.research.google.com/github/Haricharanpampad/machine-learning/blob/main/image_processing_(DeepLearning).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#getting an image using web get
# !wget 'https://m.media-amazon.com/images/I/519Hct2QoeL._AC_UF894,1000_QL80_.jpg'
# Out:
# --2026-06-29 15:21:54--  https://m.media-amazon.com/images/I/519Hct2QoeL._AC_UF894,1000_QL80_.jpg
# Resolving m.media-amazon.com (m.media-amazon.com)... 18.244.203.94, 2600:9000:2211:a200:1d:d7f6:39d6:4401, 2600:9000:2211:e000:1d:d7f6:39d6:4401, ...
# Connecting to m.media-amazon.com (m.media-amazon.com)|18.244.203.94|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 76638 (75K) [image/jpeg]
# Saving to: ‘519Hct2QoeL._AC_UF894,1000_QL80_.jpg’
#
# 519Hct2QoeL._AC_UF8 100%[===================>]  74.84K  --.-KB/s    in 0.01s
#
# 2026-06-29 15:21:54 (5.30 MB/s) - ‘519Hct2QoeL._AC_UF894,1000_QL80_.jpg’ saved [76638/76638]

# %% [markdown]
# ** libraries used for imAGE PROCESSING**
# 1.matplotlib.image
# 2.pillow
# 3.openCV(cv2)

# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt

# %%
#loading image coverted into numpy array using mpimg
img=mpimg.imread('/content/dog.jpg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape  #3 channel 1000x66
# Out:
# (1000, 666, 3)

# %%
print(img) #image coverted to numpy array
# Out:
# [[[105 130  72]
#   [106 131  73]
#   [106 134  75]
#   ...
#   [127 128 123]
#   [128 129 124]
#   [128 129 124]]
#
#  [[105 130  72]
#   [106 131  73]
#   [106 134  75]
#   ...
#   [127 128 123]
#   [128 129 124]
#   [128 129 124]]
#
#  [[103 131  70]
#   [104 132  71]
#   [106 134  73]
#   ...
#   [127 128 123]
#   [128 129 124]
#   [128 129 124]]
#
#  ...
#
#  [[ 34  94  20]
#   [ 59 121  44]
#   [ 63 127  49]
#   ...
#   [129 183  89]
#   [ 95 150  56]
#   [133 188  94]]
#
#  [[ 33  94  17]
#   [ 68 131  52]
#   [ 83 148  68]
#   ...
#   [ 79 133  37]
#   [ 71 127  30]
#   [ 94 150  53]]
#
#  [[ 42 103  25]
#   [ 59 122  43]
#   [ 51 116  36]
#   ...
#   [140 194  96]
#   [112 168  69]
#   [133 189  90]]]

# %%
#now comverting image from numpy array to image using plt
img_plot=plt.imshow(img)
plt.show()

# %% [markdown]
# #resizing image using pillow library

# %%
from PIL import Image

# %%
img=Image.open('/content/dog.jpg')
img_resized=img.resize((200,200))

# %%
img_resized.save('dog_image_resized.jpg')

# %%
img_res=mpimg.imread('/content/dog_image_resized.jpg')
img_res_plot=plt.imshow(img_res)
plt.show()

# %%
img_res.shape
# Out:
# (200, 200, 3)

# %% [markdown]
# #convert RGB to Grayscale using open CV

# %%
import cv2

# %%
img=cv2.imread('/content/dog.jpg')
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (1000, 666, 3)

# %%
grayscale_image=cv2.cvtColor(img,cv2.COLOR_RGB2GRAY)

# %%
type(grayscale_image)
# Out:
# numpy.ndarray

# %%
grayscale_image.shape #coverted to grayscale
# Out:
# (1000, 666)

# %%
from google.colab.patches import cv2_imshow

# %%
cv2_imshow(grayscale_image)
# Out:
# <PIL.Image.Image image mode=L size=666x1000>

# %%
#saving
cv2.imwrite('dog_grayscale.jpg',grayscale_image)
# Out:
# True
