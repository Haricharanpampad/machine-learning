# %% [markdown]
# <a href="https://colab.research.google.com/github/Haricharanpampad/machine-learning/blob/main/Cross_Validation_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Video Link:**
#
# K-Fold cross validation - concept ideo: https://youtu.be/dkd1eeaXbJA

# %% [markdown]
# Importing the Dependencies

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.metrics import accuracy_score

# %% [markdown]
# Importing the models

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier

# %% [markdown]
# Data Collection and Processing

# %%
# loading the csv data to a Pandas DataFrame
heart_data = pd.read_csv('/content/heart.csv')

# %%
# print first 5 rows of the dataset
heart_data.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
# number of rows and columns in the dataset
heart_data.shape
# Out:
# (303, 14)

# %%
# checking for missing values
heart_data.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
# checking the distribution of Target Variable
heart_data['target'].value_counts()
# Out:
# target
# 1    165
# 0    138
# Name: count, dtype: int64

# %% [markdown]
# 1 --> Defective Heart
#
# 0 --> Healthy Heart

# %% [markdown]
# Splitting the Features and Target

# %%
X = heart_data.drop(columns='target', axis=1)
Y = heart_data['target']

# %%
print(X)
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal
# 0        0   0     1
# 1        0   0     2
# 2        2   0     2
# ...

# %%
print(Y)
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 298    0
# 299    0
# 300    0
# 301    0
# 302    0
# Name: target, Length: 303, dtype: int64

# %% [markdown]
# #**Train Test Split**

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, stratify = Y, random_state=3)

# %%
print(X.shape, X_train.shape, X_test.shape)
# Out:
# (303, 13) (242, 13) (61, 13)

# %% [markdown]
# comparing performances of models
# ~

# %%
models=[LogisticRegression(max_iter=1000),SVC(kernel='linear'),KNeighborsClassifier(),RandomForestClassifier()]

# %%
def compare_models_train_test():
  for model in models:
    model.fit(X_train,Y_train)
    test_data_prediction=model.predict(X_test)
    accuracy=accuracy_score(Y_test,test_data_prediction)
    print("Accuracy score of the",model,"=",accuracy)

# %%
compare_models_train_test()
# Out:
# Accuracy score of the LogisticRegression(max_iter=1000) = 0.7868852459016393
# Accuracy score of the SVC(kernel='linear') = 0.7704918032786885
# Accuracy score of the KNeighborsClassifier() = 0.6557377049180327
# Accuracy score of the RandomForestClassifier() = 0.7704918032786885

# %% [markdown]
# # Cross Validation

# %% [markdown]
# Logistic Reg

# %%
cv_score_lr=cross_val_score(LogisticRegression(max_iter=1000),X,Y,cv=5)

# %%
print(cv_score_lr)
# Out:
# [0.80327869 0.86885246 0.85245902 0.86666667 0.75      ]

# %%
mean_accuracy_lr=(sum(cv_score_lr)/len(cv_score_lr))*100
mean_accuracy_lr=round(mean_accuracy_lr,2)
print(mean_accuracy_lr)
# Out:
# 82.83

# %%
#SVC

# %%
cv_score_svc=cross_val_score(SVC(kernel='linear'),X,Y,cv=5)
print(cv_score_lr)
mean_accuracy_svc=(sum(cv_score_lr)/len(cv_score_lr))*100
mean_accuracy_svc=round(mean_accuracy_lr,2)
print(mean_accuracy_svc)
# Out:
# [0.80327869 0.86885246 0.85245902 0.86666667 0.75      ]
# 82.83

# %% [markdown]
# #Creating funtion to compare models in Cross Validation

# %%
def compare_models_cross_validation():
  for model in models:
    cv_score=cross_val_score(model,X,Y,cv=5)
    mean_accuracy=(sum(cv_score)/len(cv_score))*100
    mean_accuracy=round(mean_accuracy,2)
    print('Cross val accuracies for',model,"=",cv_score)
    print('Accuracy % of the ',model,mean_accuracy)
    print("-------------------------")

# %%
compare_models_cross_validation()
# Out:
# Cross val accuracies for LogisticRegression(max_iter=1000) = [0.80327869 0.86885246 0.85245902 0.86666667 0.75      ]
# Accuracy % of the  LogisticRegression(max_iter=1000) 82.83
# -------------------------
# Cross val accuracies for SVC(kernel='linear') = [0.81967213 0.8852459  0.80327869 0.86666667 0.76666667]
# Accuracy % of the  SVC(kernel='linear') 82.83
# -------------------------
# Cross val accuracies for KNeighborsClassifier() = [0.60655738 0.6557377  0.57377049 0.73333333 0.65      ]
# Accuracy % of the  KNeighborsClassifier() 64.39
# -------------------------
# Cross val accuracies for RandomForestClassifier() = [0.81967213 0.90163934 0.78688525 0.81666667 0.75      ]
# Accuracy % of the  RandomForestClassifier() 81.5
# -------------------------
